# %%
# Requires python 3.10
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy==1.26.4 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: gspread==6.1.2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (6.1.2)
# Requirement already satisfied: oauth2client==4.1.3 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (4.1.3)
# Requirement already satisfied: df2gspread==1.0.4 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.0.4)
# Requirement already satisfied: pandas==2.2.2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: matplotlib==3.8.4 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.8.4)
# Requirement already satisfied: seaborn==0.13.2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: pandas-profiling==3.6.6 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (3.6.6)
# Requirement already satisfied: google-auth>=1.12.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from gspread==6.1.2->-r requirements.txt (line 2)) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from gspread==6.1.2->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: httplib2>=0.9.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from oauth2client==4.1.3->-r requirements.txt (line 3)) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from oauth2client==4.1.3->-r requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from oauth2client==4.1.3->-r requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from oauth2client==4.1.3->-r requirements.txt (line 3)) (4.9)
# Requirement already satisfied: six>=1.6.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from oauth2client==4.1.3->-r requirements.txt (line 3)) (1.16.0)
# Collecting argparse>=1.3.0 (from df2gspread==1.0.4->-r requirements.txt (line 4))
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: google-api-python-client==1.6.7 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from df2gspread==1.0.4->-r requirements.txt (line 4)) (1.6.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from pandas==2.2.2->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from pandas==2.2.2->-r requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from pandas==2.2.2->-r requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 6)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 6)) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 6)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from matplotlib==3.8.4->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: ydata-profiling in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from pandas-profiling==3.6.6->-r requirements.txt (line 8)) (4.12.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from google-api-python-client==1.6.7->df2gspread==1.0.4->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from google-auth>=1.12.0->gspread==6.1.2->-r requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from google-auth-oauthlib>=0.4.1->gspread==6.1.2->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: pydantic>=2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (2.9.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.7.6)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (4.66.6)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (4.4.1)
# Requirement already satisfied: imagehash==4.3.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.60.0)
# Requirement already satisfied: PyWavelets in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from numba<1,>=0.56.0->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.43.0)
# Requirement already satisfied: joblib>=0.14.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (2024.8.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread==6.1.2->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in /Users/fcorreia/myfiles/feup/thesis_2024_Duarte_Figueiredo/terraform-software-architecture-extractor-replication-package/venv/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling==3.6.6->-r requirements.txt (line 8)) (3.4.2)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
import numpy as np
import pandas as pd
from pandas.api.types import is_numeric_dtype, is_string_dtype
import gspread
import seaborn
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import textwrap
from itertools import chain
from oauth2client.service_account import ServiceAccountCredentials
import time
from collections import defaultdict
from pathlib import Path
import os

# %%
pd.set_option('display.max_rows', 6000)
pd.set_option('display.max_columns', 6000)
pd.set_option('display.width', 6000)
pd.options.display.max_colwidth = 0

# %%
data = pd.read_csv("../data/form_responses.csv")
# ProfileReport(data)

def get_column_full_name(keyword_on_column):
    for column in data.columns:
        if keyword_on_column in column:
            return column

# %%
def plot_horizontal_distribution(results, category_names, legend_lines, legend_anchor):
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.get_cmap('tab20c')(
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(12.2, 1))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        ax.barh(labels, widths, left=starts, height=0.9,
                label=colname, color=color)
        xcenters = starts + widths / 2

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        for y, (x, c) in enumerate(zip(xcenters, widths)):
            ax.text(x, y, str(int(c)) + '%', ha='center', va='center',
                    color=text_color, fontsize='x-large')
    ax.legend(ncol=int(len(category_names) / legend_lines), bbox_to_anchor=legend_anchor,
              loc='lower left', fontsize='x-large')

    return fig, ax

# %%
# countries
countries = data['Country']
results_size = len(countries)
occurrences = defaultdict(int)

for country in countries:
    if occurrences[country]:
        occurrences[country] = occurrences[country] + 1
    else:
        occurrences[country] = 1
print(f"Unique countries: {len(set(countries))}")
distribution = {key: int(round(value / results_size, 2) * 100) for key, value in occurrences.items()}
sorted_distribution = dict(sorted(distribution.items(), key=lambda item: item[1], reverse=True))
filtered_distribution = dict()
others = 0
others_percent = 0
for k, v in sorted_distribution.items():
  if v<3:
    others += 1
    others_percent += v
    continue
  filtered_distribution[k] = v
filtered_distribution["Other countries"] = others_percent
print(f"Found {others} other coutries, with representation below 3%.")
# Out:
# Unique countries: 32
# Found 22 other coutries, with representation below 3%.

# %%
category_names = list(filtered_distribution.keys())
results = {
    '': list(filtered_distribution.values())
}

plot_horizontal_distribution(results, category_names, 2.5, (0.008, -1.5))

os.makedirs("../figures",exist_ok=True)
filepath = Path('../figures/dist_country.pdf')
plt.savefig(filepath, format='pdf', bbox_inches='tight')
plt.show()

# %%
# Education level
def translate_level(level):
    if 'Primary' in level:
        return "Primary school"
    elif 'Secondary' in level:
        return "Secondary school"
    elif 'college' in level:
        return "University study without degree"
    elif 'Bachelor' in level:
        return "Bachelor's degree"
    elif 'Master' in level:
        return "Master's degree"
    elif 'Doctoral' in level:
        return "Doctoral degree"
    else:
        return 'Other'
        

education_levels = data['Educational attainment']
education_answers_size = len(education_levels)
education_occurrences = defaultdict(int)

for edl in education_levels:
    level = translate_level(edl)
    if education_occurrences[level]:
        education_occurrences[level] = education_occurrences[level] + 1
    else:
        education_occurrences[level] = 1

education_distribution = {key: round((value / education_answers_size), 2) * 100 for key, value in education_occurrences.items()}
education_sorted_distribution = dict(sorted(education_distribution.items(), key=lambda item: item[1], reverse=True))

edu_category_names = list(education_sorted_distribution.keys())
edu_results = {
    '': list(education_sorted_distribution.values())
}

plot_horizontal_distribution(edu_results, edu_category_names, 1, (-0.05, -0.7))
filepath = Path('../figures/edu_attainment.pdf')
plt.savefig(filepath, format='pdf', bbox_inches='tight')
plt.show()

# %%
# Area of study

def translate_to_computer_science(area):
    similar_areas = ['Computer', 'computer', 'Computation', 'computation', 'Informatics', 'informatics',
                     'Software', 'software', 'IT', 'informatic', 'Information', 'information']
    
    if any(x in area for x in similar_areas):
        return 'Computer Science'
    else:
        return 'Other'


study_area_column_name = get_column_full_name('study')
study_areas = data[study_area_column_name]
study_areas_answers = len(study_areas)
areas_occurrences = defaultdict(int)

for area in study_areas:
    if area != area:
        continue
    translated_area = translate_to_computer_science(area)
    if areas_occurrences[translated_area]:
        areas_occurrences[translated_area] = areas_occurrences[translated_area] + 1
    else:
        areas_occurrences[translated_area] = 1

area_distribution = {key: (value / study_areas_answers) * 100 for key, value in areas_occurrences.items()}
area_distribution_sorted = dict(sorted(area_distribution.items(), key=lambda item: item[1], reverse=True))

areas_names = list(area_distribution_sorted.keys())
area_results = {
    '': list(area_distribution_sorted.values())
}

plot_horizontal_distribution(area_results, areas_names, 1, (0.35, -0.7))
filepath = Path('../figures/area_study.pdf')
plt.savefig(filepath, format='pdf', bbox_inches='tight')
plt.show()

# %%
profexp_column_name = get_column_full_name('Professional')
prof_exp_options = data[profexp_column_name]
prof_exp_answers = len(prof_exp_options)
prof_exp_occ = defaultdict(int)

def get_prof_item_order(item):
    if '1 to 4' in item:
        return 1
    elif '5 to 9' in item:
        return 2
    elif '10 to 14' in item:
        return 3
    elif '15' in item:
        return 4
    else:
        return 0

for prof_exp in prof_exp_options:
    if prof_exp_occ[prof_exp]:
        prof_exp_occ[prof_exp] = prof_exp_occ[prof_exp] + 1
    else:
        prof_exp_occ[prof_exp] = 1

prof_exp_dist = {key: round((value / prof_exp_answers), 2) * 100 for key, value in prof_exp_occ.items()}
prof_exp_dist_sorted = dict(sorted(prof_exp_dist.items(), key=lambda item: get_prof_item_order(item[0])))
#prof_exp_dist_sorted = prof_exp_dist

prof_exp_names = list(prof_exp_dist_sorted.keys())
prof_exp_values = {
    '': list(prof_exp_dist_sorted.values())
}

plot_horizontal_distribution(prof_exp_values, prof_exp_names, 1, (-0.1, -0.7))
filepath = Path('../figures/professional_experience.pdf')
plt.savefig(filepath, format='pdf', bbox_inches='tight')
plt.show()
